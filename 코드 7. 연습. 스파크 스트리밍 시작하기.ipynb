# %%
import os
SPARK_HOME = '/Users/isang-geon/spark'
# exec(open(os.path.join(os.environ["SPARK_HOME"], 'python/pyspark/shell.py')).read())
exec(open(os.path.join(SPARK_HOME, 'python/pyspark/shell.py')).read())
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 3.0.1
#       /_/
#
# Using Python version 3.8.5 (default, Sep  4 2020 02:22:02)
# SparkSession available as 'spark'.

# %%
import re
from pyspark.streaming import StreamingContext
ssc = StreamingContext(sc,30)
lines = ssc.socketTextStream('localhost', 9999)
wordcounts = lines.filter(lambda line: len(line) > 0) \
                    .flatMap(lambda line: re.split('\W+', line)) \
                    .filter(lambda word: len(word) > 0) \
                    .map(lambda word:(word.lower(), 1)) \
                    .reduceByKey(lambda x, y: x + y)
wordcounts.pprint()
ssc.start()
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2021-02-11 18:45:00
# -------------------------------------------
# ('s', 1)
# ('now', 1)
# ('a', 1)
# ('midsummer', 1)
# ('fair', 1)
# ('hippolyta', 1)
# ('our', 1)
# ('hour', 1)
# ('night', 1)
# ('dream', 1)
# ...
#
# -------------------------------------------
# Time: 2021-02-11 18:45:30
# -------------------------------------------
# ('apace', 1)
# ('but', 2)
# ('like', 2)
# ('step', 1)
# ('out', 1)
# ('young', 1)
# ('s', 2)
# ('themselves', 1)
# ('nights', 1)
# ('silver', 1)
# ...
#
# -------------------------------------------
# Time: 2021-02-11 18:46:00
# -------------------------------------------
# ('bosom', 1)
# ('of', 5)
# ('hast', 3)
# ('interchang', 1)
# ('knacks', 1)
# ('prevailment', 1)
# ('s', 1)
# ('heart', 1)
# ('by', 1)
# ('sung', 1)
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-463ad8b079af> in <module>
#      10 wordcounts.pprint()
#      11 ssc.start()
# ---> 12 ssc.awaitTermination()
#
# /opt/anaconda3/envs/condapyspark/lib/python3.8/site-packages/pyspark/streaming/context.py in awaitTermination(self, timeout)
#     187         """
#     188         if timeout is None:
# --> 189             self._jssc.awaitTermination()
#     190         else:
#     191             self._jssc.awaitTerminationOrTimeout(int(timeout * 1000))
#
# /opt/anaconda3/envs/condapyspark/lib/python3.8/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# /opt/anaconda3/envs/condapyspark/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1031         connection = self._get_connection()
#    1032         try:
# -> 1033             response = connection.send_command(command)
#    1034             if binary:
#    1035                 return response, self._create_connection_guard(connection)
#
# /opt/anaconda3/envs/condapyspark/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1198
#    1199         try:
# -> 1200             answer = smart_decode(self.stream.readline()[:-1])
#    1201             logger.debug("Answer received: {0}".format(answer))
#    1202             if answer.startswith(proto.RETURN_MESSAGE):
#
# /opt/anaconda3/envs/condapyspark/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
# -------------------------------------------
# Time: 2021-02-11 18:46:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:47:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:47:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:48:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:48:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:49:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:49:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:50:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:50:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:51:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:51:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:52:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:52:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:53:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:53:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:54:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:54:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:55:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:55:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:56:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:56:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:57:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:57:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:58:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:58:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:59:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 18:59:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 19:00:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 19:00:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 19:01:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 19:01:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 19:02:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 19:02:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 19:03:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-02-11 19:03:30
# -------------------------------------------

# %%
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2021-02-11 18:42:30
# -------------------------------------------
# ('maid', 1)
# ('are', 1)
# ('but', 4)
# ('wax', 1)
# ('he', 1)
# ('wanting', 1)
# ('s', 1)
# ('other', 1)
# ('i', 7)
# ('would', 1)
# ...
#
# -------------------------------------------
# Time: 2021-02-11 18:43:00
# -------------------------------------------
# ('question', 1)
# ('of', 3)
# ('whe', 1)
# ('r', 1)
# ('s', 3)
# ('shady', 1)
# ('sister', 1)
# ('hymns', 1)
# ('thrice', 1)
# ('but', 1)
# ...
#
# -------------------------------------------
# Time: 2021-02-11 18:43:30
# -------------------------------------------
# ('s', 4)
# ('let', 1)
# ('he', 2)
# ('of', 3)
# ('i', 8)
# ('fairly', 1)
# ('beauteous', 1)
# ('why', 1)
# ('confess', 1)
# ('thought', 1)
# ...
#
# -------------------------------------------
# Time: 2021-02-11 18:44:00
# -------------------------------------------
# ('of', 3)
# ('egeus', 1)
# ('i', 1)
# ('against', 1)
# ('something', 1)
# ('else', 1)
# ('you', 3)
# ('which', 1)
# ('by', 1)
# ('extenuate', 1)
# ...

# %%
ssc.stop()
